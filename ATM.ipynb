# %%
class ATM:
    acbal=10000
    def withdraw(self):
      #accept amount
      #amount should be multiples of 100
      #withdraw amount should be less than acbal
      #trasaction limit is 20k
      def deposit(self):
        amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
          if amt<=50000:
           self.acbal=self.acbal+amt
          else:
            print("transaction limit is 50k only")
        else:
          print("please enter multiples of 100")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()
        elif option==2:
            obj.withdraw()


obj=ATM()
obj.viewOptions()
# Out:
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 1
# Enter your deposite amount :600000
# transaction limit is 50k only
# Avaliable bal is:  10000

# %%
#accept withdraw amount and print the number of notes

amount=int(input("enter the withdraw amount"))
five=0
two=0
one=0
if amount%100==0:
 if amount>=500:
  five=amount//500
  amount=amount-(five*500)
  print("500---",five)
  if amount>=200:
    two=amount//200
    amount=amount-(two*200)
    print("200---",two)
    if amount>=100:
      one=amount//100
      amount=amount-(one*100)
      print("100---",one)
else:
  print("please enter the multiples of 100 only")

  class ATM:
    acbal=10000
    def withdraw(self):
        amt=int(input("Enter your withdraw amount: "))
        if amt%100==0:
            if amt<=self.acbal:
                if amt<=20000:
                    self.acbal=self.acbal-amt
                else:
                    print("Transaction limit is 20k only")
            else:
                print("Insuffcient fund")
        else:
            print("Please enter multiples of 100")
    def deposit(self):
        amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
            if amt<=50000:
                self.acbal=self.acbal+amt
            else:
                print("Transaction limit is 50k only")
        else:
            print("Please enter multiples of 100")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()
        elif option==2:
            obj.withdraw()



obj=ATM()
obj.viewOptions()
# Out:
# enter the withdraw amount2
# please enter the multiples of 100 only
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 2000

# %%
class ATM:
    acbal=10000
    def numberOfNotes(self,amt):
        five=0
        two=0
        one=1
        if amt>=500:
            five=amt//500
            amt=amt-(five*500)
            print("500 rupees notes are : ",five)
        if amt>=200:
            two=amt//200
            amt=amt-(two*200)
            print("200 rupees notes are : ",two)
        if amt>=100:
            print("100 rupees notes are  ",one)

    def withdraw(self):
        amt=int(input("Enter your withdraw amount: "))
        if amt%100==0:
            if amt<=self.acbal:
                if amt<=20000:
                    self.acbal=self.acbal-amt
                    obj.numberOfNotes(amt)
                    print("Avaliable bal is: ",self.acbal)
                else:
                    print("Transaction limit is 20k only")
            else:
                print("Insuffcient fund")
        else:
            print("Please enter multiples of 100")
    def deposit(self):
        amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
            if amt<=50000:
                self.acbal=self.acbal+amt
            else:
                print("Transaction limit is 50k only")
        else:
            print("Please enter multiples of 100")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()
        elif option==2:
            obj.withdraw()
        elif option==3:
            print("available bal is:",self.acbal)
        elif option==0:
            print("thank you,visit again")
        else:
          print("please select correct option")



obj=ATM()
obj.viewOptions()
# Out:
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 0
# thank you,visit again

# %%
class ATM:
    acbal=10000
    def continue1(self):
        value=int(input("1 for continue and 0 for EXIT"))
        if value==1:
            obj.viewOptions()
        else:
            print("Thank you, Visit again")
    def numberOfNotes(self,amt):
        five=0
        two=0
        one=1
        if amt>=500:
            five=amt//500
            amt=amt-(five*500)
            print("500 rupees notes are : ",five)
        if amt>=200:
            two=amt//200
            amt=amt-(two*200)
            print("200 rupees notes are : ",two)
        if amt>=100:
            print("100 rupees notes are  ",one)

    def withdraw(self):
        amt=int(input("Enter your withdraw amount: "))
        if amt%100==0:
            if amt<=self.acbal:
                if amt<=20000:
                    self.acbal=self.acbal-amt
                    obj.numberOfNotes(amt)
                    print("Avaliable bal is: ",self.acbal)
                else:
                    print("Transaction limit is 20k only")
            else:
                print("Insuffcient fund")
        else:
            print("Please enter multiples of 100")
    def deposit(self):
        amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
            if amt<=50000:
                self.acbal=self.acbal+amt
            else:
                print("Transaction limit is 50k only")
        else:
            print("Please enter multiples of 100")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()
            obj.continue1()
        elif option==2:
            obj.withdraw()
            obj.continue1()
        elif option==3:
            print("Avaliable bal is: ",self.acbal)
            obj.continue1()
        elif option==0:
            print("Thank you, Visit again")
        else:
            print("Please select correct option ")



obj=ATM()
obj.viewOptions()
# Out:
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 1
# Enter your deposite amount :2300
# Avaliable bal is:  12300
# 1 for continue and 0 for EXIT1
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 2
# Enter your withdraw amount: 3200
# 500 rupees notes are :  6
# 200 rupees notes are :  1
# Avaliable bal is:  9100
# 1 for continue and 0 for EXIT1
# Welcome to ABC bank
# 1. Deposit
# 2. Withdraw
# 3. Balance Enquiry
# 0. EXIT
# Choose your option: 3
# Avaliable bal is:  9100
# 1 for continue and 0 for EXIT0
# Thank you, Visit again

# %%
class ATM:
    acbal=10000
    wcount=0
    def validation(self):
        pin=int(input("Enter your pin: "))
        if pin==1234:
            obj.viewOptions()
        else:
            print("Invalid pin number, try again")
    def continue1(self):
        value=int(input("1 for continue and 0 for EXIT"))
        if value==1:
            obj.viewOptions()
        else:
            print("Thank you, Visit again")
    def numberOfNotes(self,amt):
        five=0
        two=0
        one=1
        if amt>=500:
            five=amt//500
            amt=amt-(five*500)
            print("500 rupees notes are : ",five)
        if amt>=200:
            two=amt//200
            amt=amt-(two*200)
            print("200 rupees notes are : ",two)
        if amt>=100:
            print("100 rupees notes are  ",one)

    def withdraw(self):
        amt=int(input("Enter your withdraw amount: "))
        if amt%100==0:
            if amt<=self.acbal:
                if amt<=20000:
                    self.acbal=self.acbal-amt
                    obj.numberOfNotes(amt)
                    self.wcount=self.wcount+1
                    print("Avaliable bal is: ",self.acbal)
                else:
                    print("Transaction limit is 20k only")
            else:
                print("Insuffcient fund")
        else:
            print("Please enter multiples of 100")
    def deposit(self):
        amt=int(input("Enter your deposite amount :"))
        if amt%100==0:
            if amt<=50000:
                self.acbal=self.acbal+amt
            else:
                print("Transaction limit is 50k only")
        else:
            print("Please enter multiples of 100")
        print("Avaliable bal is: ",self.acbal)


    def viewOptions(self):
        print("Welcome to ABC bank ")
        print("1. Deposit")
        print("2. Withdraw")
        print("3. Balance Enquiry")
        print("0. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            obj.deposit()
            obj.continue1()
        elif option==2:
            if self.wcount<3:
                obj.withdraw()
            else:
                print("your transaction limit is over for the day")
            obj.continue1()
        elif option==3:
            print("Avaliable bal is: ",self.acbal)
            obj.continue1()
        elif option==0:
            print("Thank you, Visit again")
        else:
            print("Please select correct option ")



obj=ATM()
obj.validation()

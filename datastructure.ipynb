# %%
x=(56,"hyd", True, 9.76)
# Out:
# (56, 'hyd', True, 9.76)

# %%
a=13
if a>=18:
  print("eligible",a)
else:
  print("not eligible",a)
# Out:
# not eligible 13

# %%
age=20,23,34,12,34,21,34,12,13,14

# %%
for i in age:
  if i>=18:
    print(i,i*12)

# %%
salary=[3000,2300,4500,2133,4567]

# %%
salary.insert(2,300)

# %%
salary
# Out:
# [3000, 2300, 300, 300, 4500, 2133, 4567]

# %%
salary.append(5600)

# %%
salary
# Out:
# [3000, 2300, 300, 300, 4500, 2133, 4567, 5600]

# %%
salary.remove(2300)

# %%
salary
# Out:
# [3000, 300, 300, 4500, 2133, 4567, 5600]

# %%
salary.pop(2)
# Out:
# 300

# %%
salary.sort()

# %%
salary
# Out:
# [300, 2133, 3000, 4500, 4567, 5600]

# %%
salary.reverse()

# %%
salary
# Out:
# [5600, 4567, 4500, 3000, 2133, 300]
